# %%
import pandas as pd

# %%
pd.read_csv('mindmatv.csv').drop('Nome Completo', axis = 1)
# Out:
#      ID da resposta        Data de envio  Última página Idioma inicial  \
# 0                 4  2022-05-20 21:49:07            8.0          pt-BR
# 1                 5                  NaN            0.0          pt-BR
# 2                 6                  NaN            NaN          pt-BR
# 3                 7  2022-05-25 11:27:55            8.0          pt-BR
# 4                 8                  NaN            2.0          pt-BR
# ..              ...                  ...            ...            ...
# 110             114  2022-05-26 19:28:39            8.0          pt-BR
# 111             115  2022-05-26 19:28:36            8.0          pt-BR
# 112             116  2022-05-26 19:23:16            8.0          pt-BR
# 113             117  2022-05-26 19:24:27            8.0          pt-BR
# 114             118  2022-05-26 19:22:48            8.0          pt-BR
#
#         Semente       Data de início  Data da última ação       Idade  \
# ...

# %%
pd.read_csv('../datasets/df_perfilv.csv').drop(['Unnamed: 0', 'nome'], axis = 1).head(5)
# Out:
#    idade  sfem  smasc  sna ano  irmaos  numirmaos  lelivros  lehqs  \
# 0     15     1      0    0  1m       1          1         1      0
# 1     15     0      1    0  1m       1          1         0      0
# 2     15     1      0    0  1m       1  4 ou mais         1      0
# 3     15     0      1    0  1m       1  4 ou mais         1      1
# 4     15     0      1    0  1m       1          1         0      0
#
#    ouvemusicas  vefilmeserie lerouverfilmeserie     materia redesocial  \
# 0            1             1                Ler    História     TikTok
# 1            1             1  Ver séries/filmes  Matemática     TikTok
# 2            1             1                Ler    História     TikTok
# 3            1             1                Ler       Outra      Outra
# 4            1             1  Ver séries/filmes     Química    Twitter
#
#               horascel   videoyt      jogos tipo
# 0  Três a quatro horas  Podcasts    Celular    v
# ...

# %%
pd.read_csv('../datasets/df_perguntasv.csv').drop(['Unnamed: 0', 'pont.1'], axis = 1).head(5)
# Out:
#    1.a  1.b  1.c  2.a  2.b  2.c  3.a  3.b  3.c  4  5  pont
# 0    3    2    1    1    1    2    1    3    2  a  a     9
# 1    3    2    1    1    1    2    1    3    2  a  a     9
# 2    3    2    1    3    2    2    1    3    2  b  a     8
# 3    3    2    1    2    3    1    3    2    1  b  b     4
# 4    3    2    1    2    3    1    3    2    1  b  a     5

# %%
pd.read_csv('../datasets/df_temposv.csv').drop('Unnamed: 0', axis = 1).head(5)
# Out:
#         1       2       3       4      5   tmedio
# 0   57.25   40.19  232.63   12.35  16.17   71.718
# 1   98.60  181.82   26.39   26.86  51.70   77.074
# 2  124.65  217.88  188.12   40.08  33.51  120.848
# 3  125.72  142.05   26.45  163.99  43.82  100.406
# 4  126.19    9.34   53.62   98.62  55.61   68.676
